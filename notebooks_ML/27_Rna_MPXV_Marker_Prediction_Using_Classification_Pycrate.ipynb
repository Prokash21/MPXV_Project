# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Raw data access

import os
os.chdir('/content/drive/MyDrive/MPXV_pycaret')

# %% [markdown]
# #### **Importing the modules** ####

# %%
from glob import glob
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
ls
# Out:
#  11.2_micro_marker.csv
#  11_micro_marker.csv
#  11_MPXV_Marker_Prediction_Using_Classification_Pycrate.ipynb
#  13.2_clade_IIb_pROC.csv
#  13.2_clade_IIb_pROC.gsheet
#  13.2_MPXV_Marker_Prediction_Using_Classification_Pycrate.ipynb
#  13_clade_IIb_pROC.csv
#  27_2X_Firbro_expression_py.csv
#  27_2X_gene_expression_py.csv
#  27_Firbro_expression_py.csv
#  27_gene_expression_py.csv
#  27_Rna_MPXV_Marker_Prediction_Using_Classification_Pycrate.ipynb
#  27_shufle_Firbro_expression_py.csv
#  27_shufle_gene_expression_py.csv
#  6_micro_marker.csv
#  6_MPXV_Marker_Prediction_Using_Classification_Pycrate.ipynb
# 'Copy of 6_MPXV_Marker_Prediction_Using_Classification_Pycrate (1).ipynb'
# 'Copy of 6_MPXV_Marker_Prediction_Using_Classification_Pycrate.ipynb'
# 'Copy of DenguePrediction_Using_Regression_Pycrate.ipynb'
#  logs.log

# %% [markdown]
# #### **Load Dataset** ####

# %%
#MPXV_df = pd.read_csv("27_Firbro_expression_py.csv", index_col=0)

# %%
#MPXV_df = pd.read_csv("27_gene_expression_py.csv", index_col=0)

# %%
MPXV_df = pd.read_csv("27_2X_Firbro_expression_py.csv", index_col=0)

# %%
#MPXV_df = pd.read_csv("27_shufle_Firbro_expression_py.csv", index_col=0)

# %%
#MPXV_df = pd.read_csv("27_shufle_gene_expression_py.csv", index_col=0)

# %%
#MPXV_df = pd.read_csv("27_2X_gene_expression_py.csv", index_col=0)

# %%
display(MPXV_df.head(3))
# Out:
#              ATP1B3   ATP5F1B       BSG     GATA6      GM2A      IDH2  \
# GSM283173  4.532082  0.290765  3.371417 -4.528686  0.042329  0.743463
# GSM283177  4.824350  0.165072  3.764677 -3.810477 -0.566571  0.880840
# GSM283187  4.888760  0.478704  2.642233 -4.849222 -0.801097  0.880236
#
#               INHBA     ITGB6      NEFM     CNOT4  ...    TUBA1B    ATP5MG  \
# GSM283173 -0.543571  0.014774 -0.397641  0.018846  ...  1.755840 -0.358780
# GSM283177 -0.116810  0.166700  1.167788  0.426644  ...  1.704255 -0.834607
# GSM283187 -0.006470 -0.121641 -0.969864  1.037128  ...  1.961130 -0.320707
#
#               NFAT5      OGFR     WDR37      CBX6    CLDN15     UBXN7  \
# GSM283173 -7.070819 -0.663000 -0.835410 -0.005711  0.647372  0.472386
# GSM283177 -3.051269 -0.881786 -1.007298 -0.272991 -0.389280 -0.663183
# GSM283187 -3.888674 -0.291457 -1.414474  0.030000 -0.013571 -0.672417
#
#            FGFR1OP2  condition
# GSM283173 -0.770984          0
# GSM283177 -1.240176          0
# ...

# %% [markdown]
# #### **Data Preprocessing** ####
# ##### **Checking null entries** #####

# %%
MPXV_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, GSM283173 to GSM2834051
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ATP1B3     28 non-null     float64
#  1   ATP5F1B    28 non-null     float64
#  2   BSG        28 non-null     float64
#  3   GATA6      28 non-null     float64
#  4   GM2A       28 non-null     float64
#  5   IDH2       28 non-null     float64
#  6   INHBA      28 non-null     float64
#  7   ITGB6      28 non-null     float64
#  8   NEFM       28 non-null     float64
#  9   CNOT4      28 non-null     float64
#  10  OVGP1      28 non-null     float64
#  11  PLAGL1     28 non-null     float64
#  12  SLC8A2     28 non-null     float64
#  13  ICAM5      28 non-null     float64
#  14  XRCC4      28 non-null     float64
#  15  ZNF212     28 non-null     float64
#  16  ELL        28 non-null     float64
#  17  DHX38      28 non-null     float64
#  18  TUBA1B     28 non-null     float64
# ...

# %%
# Checking columns having null values
#MPXV_df.isna().sum()

# %%
# Getting the list of columns having missing values
#x = dengue_features.columns[dengue_features.isna().sum() > 0].tolist()
#x

# %%
# Filling the missing value with mean
#for i in x:
#    dengue_features[i] = dengue_features[i].fillna(dengue_features[i].mean())
#dengue_features.head()

# %% [markdown]
# ##### **merge dataset** #####

# %%
# Adding total cases
#dengue_features['total_cases'] = dengue_labels['total_cases']
#dengue_features.head(3)

# %% [markdown]
# ##### **Feature Engineering** #####
# The dengue cases of San Juan sj and Iquitos iq are not dependent. So splitting them into different DataFrames

# %%
#X_sj = dengue_features[dengue_features['city'] == 'sj']
#X_iq = dengue_features[dengue_features['city'] == 'iq']

# %%
# MPXV_df = MPXV_df.drop(['condition'], axis=1)
#X_iq = X_iq.drop(['city', 'weekofyear', 'week_start_date'], axis=1)

# %%
# display(MPXV_df.head(2))
#display(X_iq.head(2))

# %%
#display(X_sj.head(2))
#display(X_iq.head(2))

# %% [markdown]
# ##### **Changing the order of columns in X_sj and X_iq DataFrames** #####

# %%
# X_sj.columns

# %%
# X_sj_1 = X_sj.columns[-3:].values.tolist()
# X_sj_2 = X_sj.columns[:15].values.tolist()

# %%
# print(X_sj_1)

# %%
# years = X_sj_1 + X_sj_2
# print(years)

# %%
# X_sj = X_sj[years[::-1]].join(X_sj[X_sj.columns[:24]])
# X_sj.head(100)

# %%
# years = X_iq.columns[:23:-1].values.tolist()
# print(years)
# X_iq = X_iq[years[::-1]].join(X_iq[X_iq.columns[:24]])
# X_iq.head()

# %%
# Removing dummy variable trap
# X_sj = X_sj.drop(1990, axis=1)
# X_iq = X_iq.drop(2000, axis=1)

# %%
# x_sj_arr = X_sj.iloc[:].values
# x_iq_arr = X_iq.iloc[:].values

# %%
# y_sj = X_sj['total_cases'].values
# y_iq = X_iq['total_cases'].values

# %%
# X_sj = X_sj.drop('total_cases', axis=1).values
# X_iq = X_iq.drop('total_cases', axis=1).values

# %% [markdown]
# #### **Splitting the dataframes into train and test** ####

# %%
# !pip install pycaret

# %%
# import pycaret classification and init setup
from pycaret.classification import *
setup(MPXV_df, target = 'condition', train_size = 0.8, session_id = 123)
# setup(X_iq, target = 'total_cases', train_size = 0.8, session_id = 123)
# Out:
# <style type="text/css">
# #T_1a8d6_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1a8d6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a8d6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1a8d6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a8d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a8d6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1a8d6_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_1a8d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1a8d6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1a8d6_row1_col1" class="data row1 col1" >condition</td>
#     </tr>
#     <tr>
#       <th id="T_1a8d6_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
import pycaret
print(pycaret.__version__)
# Out:
# 3.3.2

# %% [markdown]
# ## **Compare Models** ##

# %%
# compare baseline models
best = compare_models()
print(best)
# Out:
# <style type="text/css">
# #T_62938 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# ## **Create Model**##

# %%
# create model
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_d5118_row10_col0, #T_d5118_row10_col1, #T_d5118_row10_col2, #T_d5118_row10_col3, #T_d5118_row10_col4, #T_d5118_row10_col5, #T_d5118_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d5118" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5118_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d5118_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d5118_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d5118_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d5118_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d5118_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d5118_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
# print model parameters
print(rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                        oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)

# %% [markdown]
# ## **Tune Model** ##

# %%
# tune hyperparameters of et
tuned_rf = tune_model(rf)
# Out:
# <style type="text/css">
# #T_01cb8_row10_col0, #T_01cb8_row10_col1, #T_01cb8_row10_col2, #T_01cb8_row10_col3, #T_01cb8_row10_col4, #T_01cb8_row10_col5, #T_01cb8_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_01cb8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01cb8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_01cb8_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_01cb8_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_01cb8_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_01cb8_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_01cb8_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_01cb8_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
# print tuned model
print(tuned_rf)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                        oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)

# %%
tuned_rf
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                        oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)

# %%
# to access the tuner object you can set return_tuner = True
tuned_rf, tuner = tune_model(rf, return_tuner=True)
# Out:
# <style type="text/css">
# #T_42e1c_row10_col0, #T_42e1c_row10_col1, #T_42e1c_row10_col2, #T_42e1c_row10_col3, #T_42e1c_row10_col4, #T_42e1c_row10_col5, #T_42e1c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_42e1c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42e1c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_42e1c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_42e1c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_42e1c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_42e1c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_42e1c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_42e1c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuner
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=10, random_state=None, shuffle=False),
#                    error_score=nan,
#                    estimator=Pipeline(memory=Memory(location=None),
#                                       steps=[('numerical_imputer',
#                                               TransformerWrapper(exclude=None,
#                                                                  include=['WDR37',
#                                                                           'NFAT5',
#                                                                           'ICAM5',
#                                                                           'ELL',
#                                                                           'PLAGL1',
#                                                                           'DHX38',
#                                                                           'GATA6',
# ...

# %% [markdown]
# ## **Analyze Model** ##

# %%
#plot_model(rf, plot = 'residuals')

# %%
# predicting error plot
plot_model(rf, plot = 'error')

# %%
# cooks distance plot
#plot_model(rf, plot = 'cooks')

# %%
# recursive feature elemination
plot_model(rf, plot = 'rfe')

# %%
# learning curve
plot_model(rf, plot = 'learning')

# %%
# validation curve
plot_model(rf, plot = 'vc')

# %%
# manifold learning plot
plot_model(rf, plot = 'manifold')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-5acafd40f0be> in <cell line: 2>()
#       1 # manifold learning plot
# ----> 2 plot_model(rf, plot = 'manifold')
#
# /usr/local/lib/python3.10/dist-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     962                 if globals_d[name] is None:
#     963                     raise ValueError(message)
# --> 964             return func(*args, **kwargs)
#     965
#     966         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/pycaret/classification/functional.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, verbose, display_format)
#    1723     """
#    1724
# -> 1725     return _CURRENT_EXPERIMENT.plot_model(
#    1726         estimator=estimator,
#    1727         plot=plot,
#
# ...

# %%
# plot feature importance
plot_model(rf, plot = 'feature')

# %% [markdown]
# ## **Evaluate Model** ##

# %%
# evaluate model
evaluate_model(rf)

# %% [markdown]
# ## **Finalize Model** ##

# %%
# finalize a model
finalize_model(rf)

# %% [markdown]
# ## **Prediction** ##

# %%
# predict on test set
holdout_pred = predict_model(rf)
